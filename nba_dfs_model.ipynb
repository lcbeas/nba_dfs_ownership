# %%
# build out ownership predictions
# and scores while you're at it

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from datetime import datetime, date, timedelta
import re
import json
from selenium import webdriver
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
import xgboost as xgb
from joblib import dump

# %%
def get_lineup(day = datetime.today().date(), slate_id = '1', slate_type= 'MAIN'):
    
    
    # in format YYYY-MM-DD
    plyr_site = requests.get(f"https://rotogrinders.com/lineups/nba?date={day}&site=draftkings")
    plyr_soup = BeautifulSoup(plyr_site.text, 'html.parser')
    
    p_df = pd.DataFrame(columns = ['date','slate_id', 'type', 'total_OU','team','opponent','team_OU', 'player', 'starting', 'salary','position', 'proj_fpts_roto','proj_ownr_roto'])

    # scrape https://rotogrinders.com/lineups/nba?date={day}&site=draftkings for data 
    for game in plyr_soup.find_all('li', attrs = {'data-role':'lineup-card'}):
        row = {}
        row['date'] = day
        row['slate_id'] = slate_id
        row['type'] = slate_type
        row['total_OU'],favorite,row['fav_line'] = game.find('div', attrs = {'class':'ou'}).find('div', attrs = {'class': 'sum'}).text.strip().split()
        
        
        away_team = game.find('div', attrs = {'class': 'blk away-team'})
        home_team = game.find('div', attrs = {'class': 'blk home-team'})

        away_str_cnt = 1
        for player in away_team.find_all('li' ,attrs=  {'class':'player'}):
            row['team'] = game['data-away']
            row['opponent'] = game['data-home']
            if row['team'] == favorite:
                row['favorite'] = 'YES'
            else:
                row['favorite'] = 'NO'
            row['team_OU'] = game.find('div', attrs = {'class':'ou'}).find_all('div')[0].text.strip().split('\n')[0]
            try:
                row['player'] = player.find('a').text
                row['salary'] = player['data-salary']
                row['position'] = player['data-pos']
                row['proj_fpts_roto'] = player.find('span', attrs = {'class':'fpts'}).text
                row['proj_ownr_roto'] = player.find('span', attrs = {'class':'pown'}).text
            except:
                continue
            if away_str_cnt <= 5:
                row['starting'] = 'YES'
            else: 
                row['starting'] = 'NO'
            

            away_str_cnt = away_str_cnt +  1
            
            p_df = p_df.append(row, ignore_index=True)

        home_str_cnt = 1 
        for player in home_team.find_all('li' ,attrs=  {'class':'player'}):
            row['team'] = game['data-home']
            row['opponent'] = game['data-away']
            if row['team'] == favorite:
                row['favorite'] = 'YES'
            else: 
                row['favorite'] = 'NO'
            row['team_OU'] = game.find('div', attrs = {'class':'ou'}).find_all('div')[2].text.strip().split('\n')[0]
            try:
                row['player'] = player.find('a').text
                row['salary'] = player['data-salary']
                row['position'] = player['data-pos']
                row['proj_fpts_roto'] = player.find('span', attrs = {'class':'fpts'}).text
                row['proj_ownr_roto'] = player.find('span', attrs = {'class':'pown'}).text
            except:
                continue
            if home_str_cnt <= 5:
                row['starting'] = 'YES'
            else: 
                row['starting'] = 'NO'
            

            home_str_cnt = home_str_cnt + 1
            
            p_df = p_df.append(row, ignore_index=True)
            
            
    # CLEAN UP SOME COLUMNS
    p_df['total_OU'] = p_df['total_OU'].astype(float)
    p_df['team_OU'] = p_df['team_OU'].astype(float)
    p_df['salary'] = p_df['salary'].str.strip(('$K')).replace('',0).astype(float)*1000
    p_df['proj_fpts_roto'] = p_df['proj_fpts_roto'].replace('',0).astype(float)
    p_df['proj_ownr_roto'] = pd.to_numeric(p_df['proj_ownr_roto'].str.strip('%'), errors='coerce')/100
            
    return p_df



def supp_stats(lineup):
    
    pass



def get_day_ownership(dt = datetime.today().strftime('%Y-%m-%d')):
    # the date gives ownership for that day (posted on website next day)
    # might have to open up executable driver file once before
    a = datetime.strptime(dt, '%Y-%m-%d').date() - date(2020, 9, 2)
    day = a.days + 1326
    driver = webdriver.Firefox(executable_path=r'C:\Users\Luke\geckodriver.exe')
    driver.get(f"https://www.linestarapp.com/Ownership/Sport/NBA/Site/DraftKings/PID/{day}")
    try:
        projected = driver.execute_script('return actualResultsDict')
    except: 
        return None
    if len(projected) == 0 :
        return None
    
    df = pd.DataFrame(list(projected.values())[0]).drop_duplicates()
    df = df.replace(r"&#39;", "'", regex= True)
    
    return df


def build_train_set(start_date, end_date):
    start_date = datetime.strptime(start_date, '%Y-%m-%d').date()
    end_date = datetime.strptime(end_date, '%Y-%m-%d').date()
    day_count = (end_date - start_date).days + 1

    final_df = pd.DataFrame()

    for single_date in (start_date + timedelta(n) for n in range(day_count)):
        single_date_ = single_date.strftime('%Y-%m-%d')
        ownership = get_day_ownership(dt = single_date_)
        if ownership is None:
            continue
        lineup = get_lineup(day = single_date_)
        merged_data = pd.merge(lineup, ownership, left_on = 'player', right_on = 'name')
        final_df = final_df.append(merged_data)
        
    target = final_df['owned']/100
    train = final_df.drop(['owned'], axis = 1)
        
    return train, target

def train_model(train, target, model = LinearRegression()):
    pipe = make_pipeline(OneHotEncoder(handle_unknown = 'ignore'), model)
    mod = pipe.fit(train, target)
    return mod

def pred_ownership(model, df):
    df['predict'] = model.predict(df)
    return df

# %%
X, y = build_train_set(start_date = '2020-09-05',end_date  = '2020-09-15')

# %%
model = train_model(X,y)
today_slate, true_vals = build_train_set(start_date = '2020-09-08', end_date = '2020-09-08')

# %%
dump(model, filename = "dfs_model.joblib")
# Out:
# ['dfs_model.joblib']

# %%
predictions = pred_ownership(model, today_slate)
predictions['true_vals'] = true_vals
predictions
# Out:
#           date slate_id  type  total_OU team_x opponent  team_OU  \
# 0   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 1   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 2   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 3   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 4   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 5   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 6   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 7   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 8   2020-09-08        1  MAIN     219.5    MIA      MIL   112.50
# 9   2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 10  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 11  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 12  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 13  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 14  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 15  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 16  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 17  2020-09-08        1  MAIN     219.5    MIL      MIA   107.00
# 18  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 19  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 20  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 21  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 22  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 23  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 24  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 25  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 26  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 27  2020-09-08        1  MAIN     222.0    LAL      HOU   113.25
# 28  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 29  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 30  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 31  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 32  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 33  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 34  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
# 35  2020-09-08        1  MAIN     222.0    HOU      LAL   108.75
#
#                       player starting   salary  ... proj_ownr_roto  fav_line  \
# 0               Goran Dragic      YES   7200.0  ...          0.195      -5.5
# 1               Jimmy Butler      YES   8500.0  ...          0.219      -5.5
# 2            Duncan Robinson      YES   4700.0  ...          0.164      -5.5
# 3                Jae Crowder      YES   5800.0  ...          0.312      -5.5
# 4                Bam Adebayo      YES   8700.0  ...          0.289      -5.5
# 5                Tyler Herro       NO   5300.0  ...          0.234      -5.5
# 6               Kelly Olynyk       NO   3300.0  ...          0.055      -5.5
# 7             Andre Iguodala       NO   3400.0  ...          0.070      -5.5
# 8              Kendrick Nunn       NO   3200.0  ...          0.001      -5.5
# 9               Eric Bledsoe      YES   6200.0  ...          0.383      -5.5
# 10          Donte DiVincenzo      YES   3500.0  ...          0.625      -5.5
# 11           Wesley Matthews      YES   3400.0  ...          0.109      -5.5
# 12           Khris Middleton      YES   8600.0  ...          0.476      -5.5
# 13               Brook Lopez      YES   6000.0  ...          0.430      -5.5
# 14               George Hill       NO   4400.0  ...          0.305      -5.5
# 15           Pat Connaughton       NO   3200.0  ...          0.016      -5.5
# 16           Marvin Williams       NO   3600.0  ...          0.133      -5.5
# 17               Kyle Korver       NO   3100.0  ...          0.008      -5.5
# 18              LeBron James      YES  11200.0  ...          0.500      -4.5
# 19  Kentavious Caldwell-Pope      YES   3600.0  ...          0.203      -4.5
# 20               Danny Green      YES   4200.0  ...          0.203      -4.5
# 21             Anthony Davis      YES  10600.0  ...          0.554      -4.5
# 22              JaVale McGee      YES   3200.0  ...          0.086      -4.5
# 23                Kyle Kuzma       NO   4800.0  ...          0.148      -4.5
# 24               Rajon Rondo       NO   3900.0  ...          0.594      -4.5
# 25               Alex Caruso       NO   3800.0  ...          0.266      -4.5
# 26           Markieff Morris       NO   3500.0  ...          0.195      -4.5
# 27             Dwight Howard       NO   3700.0  ...          0.001      -4.5
# 28         Russell Westbrook      YES   8400.0  ...          0.320      -4.5
# 29              James Harden      YES  11000.0  ...          0.156      -4.5
# 30               Eric Gordon      YES   5900.0  ...          0.086      -4.5
# 31          Robert Covington      YES   6500.0  ...          0.266      -4.5
# 32               P.J. Tucker      YES   4900.0  ...          0.187      -4.5
# 33                Jeff Green       NO   4000.0  ...          0.078      -4.5
# 34             Austin Rivers       NO   3200.0  ...          0.001      -4.5
# 35              Ben McLemore       NO   3000.0  ...          0.001      -4.5
#
#     favorite    id                      name    pos    sal team_y   predict  \
# 0        YES   219              Goran Dragic     PG   7200    MIA  0.281541
# 1        YES   102              Jimmy Butler  SG/SF   8500    MIA  0.257392
# 2        YES   994           Duncan Robinson  SG/SF   4700    MIA  0.312597
# 3        YES     3               Jae Crowder     PF   5800    MIA  0.525407
# 4        YES   852               Bam Adebayo      C   8700    MIA  0.239775
# 5        YES  1156               Tyler Herro     SG   5300    MIA  0.244402
# 6        YES    11              Kelly Olynyk   PF/C   3300    MIA  0.073668
# 7        YES   301            Andre Iguodala     SF   3400    MIA  0.019200
# 8        YES  1013             Kendrick Nunn  PG/SG   3200    MIA  0.065021
# 9         NO   345              Eric Bledsoe     PG   6200    MIL  0.310135
# 10        NO   988          Donte DiVincenzo  PG/SG   3500    MIL  0.243222
# 11        NO   408           Wesley Matthews     SG   3400    MIL  0.004829
# 12        NO   188           Khris Middleton     SF   8600    MIL  0.247321
# 13        NO    34               Brook Lopez      C   6000    MIL  0.300333
# 14        NO   169               George Hill     PG   4400    MIL  0.255058
# 15        NO   517           Pat Connaughton     SF   3200    MIL  0.079465
# 16        NO   289           Marvin Williams     PF   3600    MIL  0.261570
# 17        NO   202               Kyle Korver  SG/SF   3100    MIL  0.129105
# 18       YES   126              LeBron James  PG/SF  11200    LAL  0.274138
# 19       YES   145  Kentavious Caldwell-Pope  SG/SF   3600    LAL  0.391492
# 20       YES   446               Danny Green  SG/SF   4200    LAL  0.293203
# 21       YES   387             Anthony Davis   PF/C  10600    LAL  0.364084
# 22       YES   409              JaVale McGee      C   3200    LAL  0.236598
# 23       YES   877                Kyle Kuzma  SF/PF   4800    LAL  0.242102
# 24       YES   378               Rajon Rondo     PG   3900    LAL  0.184346
# 25       YES   789               Alex Caruso  PG/SG   3800    LAL  0.159727
# 26       YES   354           Markieff Morris   PF/C   3500    LAL  0.118156
# 27       YES   427             Dwight Howard      C   3700    LAL  0.007092
# 28        NO   549         Russell Westbrook     PG   8400    HOU  0.328254
# 29        NO   425              James Harden  PG/SG  11000    HOU  0.285825
# 30        NO   392               Eric Gordon  SG/SF   5900    HOU  0.240535
# 31        NO    62          Robert Covington  SF/PF   6500    HOU  0.291278
# 32        NO   358               P.J. Tucker      C   4900    HOU  0.252747
# 33        NO   466                Jeff Green      C   4000    HOU  0.151155
# 34        NO   322             Austin Rivers  PG/SG   3200    HOU  0.079147
# 35        NO   376              Ben McLemore  SG/SF   3000    HOU  0.094001
#
#    true_vals
# 0     0.2278
# 1     0.3103
# 2     0.3371
# 3     0.2960
# 4     0.3708
# 5     0.1255
# 6     0.0464
# 7     0.0235
# 8     0.0111
# 9     0.4724
# 10    0.5347
# 11    0.0244
# 12    0.6327
# 13    0.3272
# 14    0.2998
# 15    0.0358
# 16    0.2326
# 17    0.0108
# 18    0.3473
# 19    0.0909
# 20    0.1512
# 21    0.4169
# 22    0.0155
# 23    0.1659
# 24    0.7260
# 25    0.0659
# 26    0.2261
# 27    0.0127
# 28    0.2595
# 29    0.1440
# 30    0.2918
# 31    0.2131
# 32    0.3029
# 33    0.1118
# 34    0.0115
# 35    0.0139
#
# [36 rows x 22 columns]

# %%
get_lineup('2020-08-10')
# Out:
#            date slate_id  type  total_OU team opponent  team_OU  \
# 0    2020-08-10        1  MAIN     220.5  OKC      PHO   106.25
# 1    2020-08-10        1  MAIN     220.5  OKC      PHO   106.25
# 2    2020-08-10        1  MAIN     220.5  OKC      PHO   106.25
# 3    2020-08-10        1  MAIN     220.5  OKC      PHO   106.25
# 4    2020-08-10        1  MAIN     220.5  OKC      PHO   106.25
# ..          ...      ...   ...       ...  ...      ...      ...
# 126  2020-08-10        1  MAIN     223.0  LAL      DEN   114.00
# 127  2020-08-10        1  MAIN     223.0  LAL      DEN   114.00
# 128  2020-08-10        1  MAIN     223.0  LAL      DEN   114.00
# 129  2020-08-10        1  MAIN     223.0  LAL      DEN   114.00
# 130  2020-08-10        1  MAIN     223.0  LAL      DEN   114.00
#
#                    player starting  salary position  proj_fpts_roto  \
# 0              Chris Paul      YES  8200.0       PG            33.3
# 1                 Lu Dort      YES  4000.0    SG/SF            18.5
# 2             Abdel Nader      YES  3000.0       PF            20.3
# 3           Darius Bazley      YES  3300.0       PF            45.0
# 4            Mike Muscala      YES  3200.0        C            25.0
# ..                    ...      ...     ...      ...             ...
# 126   Talen Horton-Tucker       NO  3000.0       SG             0.0
# 127       Markieff Morris       NO  3000.0     PF/C            17.8
# 128          Jared Dudley       NO  3000.0    SF/PF             0.0
# 129        Devontae Cacok       NO  3000.0       PF             0.0
# 130  Kostas Antetokounmpo       NO  3000.0       PF             0.0
#
#      proj_ownr_roto fav_line favorite
# 0             0.251       -8       NO
# 1             0.030       -8       NO
# 2             0.001       -8       NO
# 3             0.341       -8       NO
# 4             0.351       -8       NO
# ..              ...      ...      ...
# 126             NaN       -5      YES
# 127             NaN       -5      YES
# 128             NaN       -5      YES
# 129             NaN       -5      YES
# 130             NaN       -5      YES
#
# [131 rows x 15 columns]

# %%
get_day_ownership(dt = '2020-08-2')
# Out:
#       id                     name  owned    pos    sal team
# 0    166              Paul George  88.47     SF   7900  LAC
# 1   1063       Michael Porter Jr.  87.60  SF/PF   3000  DEN
# 2    447            Kawhi Leonard  81.29     SF   8900  LAC
# 3    489             Nikola Jokic  80.10      C   9000  DEN
# 4    331          Jordan Clarkson  74.12  PG/SG   3900  UTA
# 5    910             Monte Morris  66.56     PG   3500  DEN
# 6     63              Joel Embiid  39.15      C   9700  PHI
# 7    927         Donovan Mitchell  38.23  PG/SG   6900  UTA
# 8    986            Aaron Holiday  33.66  PG/SG   4000  IND
# 9    152           Reggie Jackson  30.67     PG   4100  LAC
# 10   102             Jimmy Butler  17.67  SG/SF   7600  MIA
# 11   175             Myles Turner  12.13      C   6200  IND
# 12   913             Torrey Craig  10.82  SG/SF   3000  DEN
# 13   463              Mike Conley   9.52     PG   5400  UTA
# 14   126             LeBron James   9.19  PG/SF  10900  LAL
# 15   199           Justin Holiday   7.07  SG/SF   3300  IND
# 16    88               Kyle Lowry   6.80     PG   8000  TOR
# 17   558              Rudy Gobert   5.82      C   7000  UTA
# 18   676              Ben Simmons   5.22  PG/SF   8600  PHI
# 19   483         Danilo Gallinari   5.17  SF/PF   5600  OKC
# 20   359              T.J. Warren   4.84  SF/PF   5800  IND
# 21   532             Steven Adams   4.84      C   5300  OKC
# 22    64             Jerami Grant   4.02     PF   4000  DEN
# 23   318               Chris Paul   3.70     PG   7400  OKC
# 24   321                JJ Redick   3.59  SG/SF   3500   NO
# 25  1016  Shai Gilgeous-Alexander   3.43  PG/SG   6800  OKC
# 26   852              Bam Adebayo   2.99      C   8100  MIA
# 27   204             Paul Millsap   2.39     PF   4900  DEN
# 28   734           Brandon Ingram   2.23  SF/PF   7800   NO
# 29   467           JaMychal Green   1.47   PF/C   3500  LAC

# %% [markdown]
# # Scratch

# %%
day = '1325'
results_site = requests.get(f"https://www.linestarapp.com/Ownership/Sport/NBA/Site/DraftKings/PID/{day}")
results_soup = BeautifulSoup(results_site.text, 'html.parser')
table = results_soup.find_all('tbody') #, attrs = {'id':'tableTournament'})

results_soup.find_all('script')
# Out:
# [<script src="/Resources/libraries/jQuery/01_09_01/jquery.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Resources/libraries/jQuery-Migrate/01_02_01/jquery-migrate.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Resources/libraries/jQuery-UI/01_11_03/jquery-ui.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Portals/_default/Skins/FantasySportsSkins/DDRMenu/TWMenu/TWMenu.js" type="text/javascript"></script>,
#  <script src="/Telerik.Web.UI.WebResource.axd?_TSM_HiddenField_=ScriptManager_TSM&amp;compress=1&amp;_TSM_CombinedScripts_=%3b%3bSystem.Web.Extensions%2c+Version%3d4.0.0.0%2c+Culture%3dneutral%2c+PublicKeyToken%3d31bf3856ad364e35%3aen-US%3a2d39c544-8ec0-4a2c-bc21-04e23af02570%3aea597d4b%3ab25378d2%3bTelerik.Web.UI%2c+Version%3d2013.2.717.40%2c+Culture%3dneutral%2c+PublicKeyToken%3d121fae78165ba3d4%3aen-US%3aa713c6a1-0827-4380-88eb-63855ca4c2d9%3a16e4e7cd%3af7645509%3aed16cbdc" type="text/javascript"></script>,
#  <script src="/js/dnn.js?cdv=61" type="text/javascript"></script>,
#  <script src="/js/dnn.modalpopup.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Resources/Shared/Scripts/jquery/jquery.hoverIntent.min.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Resources/Shared/Scripts/dnn.jquery.js?cdv=61" type="text/javascript"></script>,
#  <script src="/js/dnncore.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Portals/_default/Skins/FantasySportsSkins/js/owl.carousel.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Portals/_default/Skins/FantasySportsSkins/js/bootstrap.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Portals/_default/Skins/FantasySportsSkins/js/Common.js?cdv=61" type="text/javascript"></script>,
#  <script src="/Portals/_default/Skins/FantasySportsSkins/js/jquery.prettyPhoto.js?cdv=61" type="text/javascript"></script>,
#  <script type="text/javascript">
#  //<![CDATA[
#  Sys.WebForms.PageRequestManager._initialize('ScriptManager', 'Form', ['tdnn$ctr587$dnn$ctr587$Login_UPPanel',''], [], [], 90, '');
#  //]]>
#  </script>,
#  <script src="https://code.highcharts.com/highcharts.js"></script>,
#  <script src="https://code.highcharts.com/highcharts-3d.js"></script>,
#  <script src="/portals/0/js/bootstrap-sortable.js" type="text/javascript"></script>,
#  <script src="/portals/0/js/fantasysportsco.playerpop.js?v=4" type="text/javascript"></script>,
#  <script src="/portals/0/js/fantasysportsco.chart.js?v=10" type="text/javascript"></script>,
#  <script>
#      var selectedPos = null;
#      var selProjectedSlateId = 11521;
#      var selResultIdx = 0;
#      var slates = [
#              {id:11521,name:'Late Swap, Main', games:2 },
#              {id:11521,name:'Late Swap, Main', games:2 },
#              {id:11521,name:'Late Swap, Main', games:2 },
#      ];
#
#      var posMap = {
#             'PG' : 'PG',
#             'SG' : 'SG',
#             'SF' : 'SF',
#             'PF' : 'PF',
#             'C' : 'C',
#             'G' : 'PG,SG',
#             'F' : 'SF,PF',
#             'UTIL' : 'PG,SG,SF,PF,C',
#      };
#
#      var projectedSlatesDict = {
#         '11521' : [
#           {id:463,name:"Mike Conley", owned:42.48, pos:'PG', team:'UTA', sal:6800 },
#           {id:91,name:"Norman Powell", owned:41, pos:'SG/SF', team:'TOR', sal:4900 },
#           {id:779,name:"Jamal Murray", owned:39.92, pos:'PG/SG', team:'DEN', sal:9700 },
#           {id:286,name:"Kemba Walker", owned:37.95, pos:'PG', team:'BOS', sal:7600 },
#           {id:689,name:"Fred VanVleet", owned:35.52, pos:'PG/SG', team:'TOR', sal:7800 },
#           {id:331,name:"Jordan Clarkson", owned:34.68, pos:'PG/SG', team:'UTA', sal:5400 },
#           {id:489,name:"Nikola Jokic", owned:34.38, pos:'C', team:'DEN', sal:9500 },
#           {id:558,name:"Rudy Gobert", owned:29.64, pos:'C', team:'UTA', sal:7900 },
#           {id:802,name:"Jayson Tatum", owned:29.48, pos:'SF/PF', team:'BOS', sal:9200 },
#           {id:1063,name:"Michael Porter Jr.", owned:28.56, pos:'SF/PF', team:'DEN', sal:5500 },
#           {id:686,name:"Pascal Siakam", owned:27.51, pos:'PF', team:'TOR', sal:8000 },
#           {id:928,name:"Royce O&#39;Neale", owned:25.16, pos:'SF/PF', team:'UTA', sal:4500 },
#           {id:927,name:"Donovan Mitchell", owned:25.12, pos:'PG/SG', team:'UTA', sal:9900 },
#           {id:537,name:"Serge Ibaka", owned:24.5, pos:'C', team:'TOR', sal:6200 },
#           {id:828,name:"OG Anunoby", owned:21.88, pos:'SF/PF', team:'TOR', sal:4800 },
#           {id:810,name:"Daniel Theis", owned:21.64, pos:'PF/C', team:'BOS', sal:5200 },
#           {id:562,name:"Joe Ingles", owned:21.6, pos:'SG/SF', team:'UTA', sal:5300 },
#           {id:14,name:"Marcus Smart", owned:19.24, pos:'PG/SG', team:'BOS', sal:6000 },
#           {id:658,name:"Jaylen Brown", owned:18, pos:'SG/SF', team:'BOS', sal:7300 },
#           {id:88,name:"Kyle Lowry", owned:16.77, pos:'PG', team:'TOR', sal:7700 },
#           {id:64,name:"Jerami Grant", owned:14.88, pos:'SF/PF', team:'DEN', sal:5100 },
#           {id:868,name:"Chris Boucher", owned:14.52, pos:'PF/C', team:'TOR', sal:3000 },
#           {id:465,name:"Marc Gasol", owned:13.54, pos:'C', team:'TOR', sal:4100 },
#           {id:910,name:"Monte Morris", owned:10.92, pos:'PG', team:'DEN', sal:4200 },
#           {id:204,name:"Paul Millsap", owned:10.44, pos:'PF/C', team:'DEN', sal:4700 },
#           {id:538,name:"Enes Kanter", owned:6.2, pos:'C', team:'BOS', sal:3400 },
#           {id:913,name:"Torrey Craig", owned:6.15, pos:'SG/SF', team:'DEN', sal:3600 },
#           {id:28,name:"Rondae Hollis-Jefferson", owned:5.6, pos:'PF/C', team:'TOR', sal:3200 },
#           {id:1103,name:"Romeo Langford", owned:5.22, pos:'SG/SF', team:'BOS', sal:3000 },
#           {id:893,name:"PJ Dozier", owned:5.12, pos:'PG/SG', team:'DEN', sal:3000 },
#           {id:529,name:"Mason Plumlee", owned:4.08, pos:'C', team:'DEN', sal:3300 },
#           {id:1123,name:"Terence Davis", owned:4, pos:'PG/SG', team:'TOR', sal:3400 },
#           {id:701,name:"Georges Niang", owned:3.4, pos:'SF/PF', team:'UTA', sal:3500 },
#           {id:1104,name:"Grant Williams", owned:2.96, pos:'SF/PF', team:'BOS', sal:3100 },
#           {id:485,name:"Gary Harris", owned:2.73, pos:'SG', team:'DEN', sal:3900 },
#           {id:952,name:"Brad Wanamaker", owned:1.89, pos:'PG', team:'BOS', sal:3500 },
#         ],
#      };
#
#      var actualResultsDict = {
#              '0' : [
#               {id:810,name:"Daniel Theis", owned:53.99, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:53.99, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:53.99, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:828,name:"OG Anunoby", owned:49.1, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:49.1, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:49.1, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:49.1, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:779,name:"Jamal Murray", owned:48.67, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:779,name:"Jamal Murray", owned:48.67, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:928,name:"Royce O&#39;Neale", owned:38.5, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:38.5, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:38.5, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:38.5, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:465,name:"Marc Gasol", owned:36.45, pos:'C', team:'TOR', sal:4100 },
#               {id:465,name:"Marc Gasol", owned:36.45, pos:'C', team:'TOR', sal:4100 },
#               {id:658,name:"Jaylen Brown", owned:34.76, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:34.76, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:34.76, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:34.76, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:34.76, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:927,name:"Donovan Mitchell", owned:34.35, pos:'PG/SG', team:'UTA', sal:9900 },
#               {id:64,name:"Jerami Grant", owned:33.81, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:33.81, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:33.81, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:689,name:"Fred VanVleet", owned:33.68, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:33.68, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:33.68, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:33.68, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:286,name:"Kemba Walker", owned:33.61, pos:'PG', team:'BOS', sal:7600 },
#               {id:286,name:"Kemba Walker", owned:33.61, pos:'PG', team:'BOS', sal:7600 },
#               {id:286,name:"Kemba Walker", owned:33.61, pos:'PG', team:'BOS', sal:7600 },
#               {id:14,name:"Marcus Smart", owned:32.41, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:32.41, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:32.41, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:32.41, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:953,name:"Robert Williams", owned:31.05, pos:'C', team:'BOS', sal:3300 },
#               {id:953,name:"Robert Williams", owned:31.05, pos:'C', team:'BOS', sal:3300 },
#               {id:463,name:"Mike Conley", owned:30.1, pos:'PG', team:'UTA', sal:6800 },
#               {id:88,name:"Kyle Lowry", owned:28.46, pos:'PG', team:'TOR', sal:7700 },
#               {id:88,name:"Kyle Lowry", owned:28.46, pos:'PG', team:'TOR', sal:7700 },
#               {id:88,name:"Kyle Lowry", owned:28.46, pos:'PG', team:'TOR', sal:7700 },
#               {id:489,name:"Nikola Jokic", owned:28.23, pos:'C', team:'DEN', sal:9500 },
#               {id:91,name:"Norman Powell", owned:27.88, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:27.88, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:27.88, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:27.88, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:27.88, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:331,name:"Jordan Clarkson", owned:25.33, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:331,name:"Jordan Clarkson", owned:25.33, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:537,name:"Serge Ibaka", owned:22.52, pos:'C', team:'TOR', sal:6200 },
#               {id:537,name:"Serge Ibaka", owned:22.52, pos:'C', team:'TOR', sal:6200 },
#               {id:802,name:"Jayson Tatum", owned:22.38, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:22.38, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:22.38, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:22.38, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:913,name:"Torrey Craig", owned:20.06, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:20.06, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:20.06, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:686,name:"Pascal Siakam", owned:18.91, pos:'PF', team:'TOR', sal:8000 },
#               {id:686,name:"Pascal Siakam", owned:18.91, pos:'PF', team:'TOR', sal:8000 },
#               {id:1063,name:"Michael Porter Jr.", owned:18.34, pos:'SF/PF', team:'DEN', sal:5500 },
#               {id:562,name:"Joe Ingles", owned:17.82, pos:'SG/SF', team:'UTA', sal:5300 },
#               {id:562,name:"Joe Ingles", owned:17.82, pos:'SG/SF', team:'UTA', sal:5300 },
#               {id:562,name:"Joe Ingles", owned:17.82, pos:'SG/SF', team:'UTA', sal:5300 },
#               {id:952,name:"Brad Wanamaker", owned:14.15, pos:'PG', team:'BOS', sal:3500 },
#               {id:952,name:"Brad Wanamaker", owned:14.15, pos:'PG', team:'BOS', sal:3500 },
#               {id:952,name:"Brad Wanamaker", owned:14.15, pos:'PG', team:'BOS', sal:3500 },
#               {id:558,name:"Rudy Gobert", owned:13.45, pos:'C', team:'UTA', sal:7900 },
#               {id:558,name:"Rudy Gobert", owned:13.45, pos:'C', team:'UTA', sal:7900 },
#               {id:701,name:"Georges Niang", owned:13.21, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:701,name:"Georges Niang", owned:13.21, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:701,name:"Georges Niang", owned:13.21, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:701,name:"Georges Niang", owned:13.21, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:485,name:"Gary Harris", owned:10.17, pos:'SG', team:'DEN', sal:3900 },
#               {id:485,name:"Gary Harris", owned:10.17, pos:'SG', team:'DEN', sal:3900 },
#               {id:485,name:"Gary Harris", owned:10.17, pos:'SG', team:'DEN', sal:3900 },
#               {id:204,name:"Paul Millsap", owned:8.83, pos:'PF/C', team:'DEN', sal:4700 },
#               {id:910,name:"Monte Morris", owned:7.58, pos:'PG', team:'DEN', sal:4200 },
#               {id:538,name:"Enes Kanter", owned:1.84, pos:'C', team:'BOS', sal:3400 },
#               {id:538,name:"Enes Kanter", owned:1.84, pos:'C', team:'BOS', sal:3400 },
#               {id:1123,name:"Terence Davis", owned:1.64, pos:'PG/SG', team:'TOR', sal:3400 },
#               {id:529,name:"Mason Plumlee", owned:1.47, pos:'C', team:'DEN', sal:3300 },
#               {id:893,name:"PJ Dozier", owned:1.23, pos:'PG/SG', team:'DEN', sal:3000 },
#               {id:893,name:"PJ Dozier", owned:1.23, pos:'PG/SG', team:'DEN', sal:3000 },
#          ],
#              '1' : [
#               {id:828,name:"OG Anunoby", owned:76.94, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:76.94, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:810,name:"Daniel Theis", owned:64.58, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:64.58, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:64.58, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:88,name:"Kyle Lowry", owned:59.97, pos:'PG', team:'TOR', sal:7700 },
#               {id:88,name:"Kyle Lowry", owned:59.97, pos:'PG', team:'TOR', sal:7700 },
#               {id:658,name:"Jaylen Brown", owned:56.14, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:56.14, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:56.14, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:56.14, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:465,name:"Marc Gasol", owned:53.96, pos:'C', team:'TOR', sal:4100 },
#               {id:465,name:"Marc Gasol", owned:53.96, pos:'C', team:'TOR', sal:4100 },
#               {id:928,name:"Royce O&#39;Neale", owned:52.83, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:52.83, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:52.83, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:52.83, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:953,name:"Robert Williams", owned:50.39, pos:'C', team:'BOS', sal:3300 },
#               {id:953,name:"Robert Williams", owned:50.39, pos:'C', team:'BOS', sal:3300 },
#               {id:779,name:"Jamal Murray", owned:47.61, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:779,name:"Jamal Murray", owned:47.61, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:779,name:"Jamal Murray", owned:47.61, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:489,name:"Nikola Jokic", owned:42.04, pos:'C', team:'DEN', sal:9500 },
#               {id:689,name:"Fred VanVleet", owned:41.25, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:41.25, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:41.25, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:286,name:"Kemba Walker", owned:34.2, pos:'PG', team:'BOS', sal:7600 },
#               {id:286,name:"Kemba Walker", owned:34.2, pos:'PG', team:'BOS', sal:7600 },
#               {id:64,name:"Jerami Grant", owned:30.11, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:30.11, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:30.11, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:14,name:"Marcus Smart", owned:29.85, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:29.85, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:29.85, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:331,name:"Jordan Clarkson", owned:20.71, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:927,name:"Donovan Mitchell", owned:19.93, pos:'PG/SG', team:'UTA', sal:9900 },
#               {id:927,name:"Donovan Mitchell", owned:19.93, pos:'PG/SG', team:'UTA', sal:9900 },
#               {id:802,name:"Jayson Tatum", owned:17.23, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:17.23, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:17.23, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:913,name:"Torrey Craig", owned:14.62, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:463,name:"Mike Conley", owned:13.4, pos:'PG', team:'UTA', sal:6800 },
#               {id:463,name:"Mike Conley", owned:13.4, pos:'PG', team:'UTA', sal:6800 },
#               {id:463,name:"Mike Conley", owned:13.4, pos:'PG', team:'UTA', sal:6800 },
#               {id:952,name:"Brad Wanamaker", owned:13.05, pos:'PG', team:'BOS', sal:3500 },
#               {id:686,name:"Pascal Siakam", owned:12.53, pos:'PF', team:'TOR', sal:8000 },
#               {id:686,name:"Pascal Siakam", owned:12.53, pos:'PF', team:'TOR', sal:8000 },
#               {id:1063,name:"Michael Porter Jr.", owned:8.62, pos:'SF/PF', team:'DEN', sal:5500 },
#               {id:91,name:"Norman Powell", owned:7.31, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:562,name:"Joe Ingles", owned:5.66, pos:'SG/SF', team:'UTA', sal:5300 },
#               {id:537,name:"Serge Ibaka", owned:5.05, pos:'C', team:'TOR', sal:6200 },
#               {id:558,name:"Rudy Gobert", owned:4.61, pos:'C', team:'UTA', sal:7900 },
#               {id:204,name:"Paul Millsap", owned:4.18, pos:'PF/C', team:'DEN', sal:4700 },
#               {id:485,name:"Gary Harris", owned:2.96, pos:'SG', team:'DEN', sal:3900 },
#               {id:910,name:"Monte Morris", owned:1.74, pos:'PG', team:'DEN', sal:4200 },
#          ],
#              '2' : [
#               {id:810,name:"Daniel Theis", owned:56.25, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:56.25, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:56.25, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:810,name:"Daniel Theis", owned:56.25, pos:'PF/C', team:'BOS', sal:5200 },
#               {id:779,name:"Jamal Murray", owned:52.27, pos:'PG/SG', team:'DEN', sal:9700 },
#               {id:828,name:"OG Anunoby", owned:48.91, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:48.91, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:48.91, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:828,name:"OG Anunoby", owned:48.91, pos:'SF/PF', team:'TOR', sal:4800 },
#               {id:927,name:"Donovan Mitchell", owned:38.1, pos:'PG/SG', team:'UTA', sal:9900 },
#               {id:928,name:"Royce O&#39;Neale", owned:35.12, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:35.12, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:35.12, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:928,name:"Royce O&#39;Neale", owned:35.12, pos:'SF/PF', team:'UTA', sal:4500 },
#               {id:64,name:"Jerami Grant", owned:34.02, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:34.02, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:64,name:"Jerami Grant", owned:34.02, pos:'SF/PF', team:'DEN', sal:5100 },
#               {id:658,name:"Jaylen Brown", owned:33.75, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:33.75, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:33.75, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:33.75, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:658,name:"Jaylen Brown", owned:33.75, pos:'SG/SF', team:'BOS', sal:7300 },
#               {id:465,name:"Marc Gasol", owned:31.73, pos:'C', team:'TOR', sal:4100 },
#               {id:465,name:"Marc Gasol", owned:31.73, pos:'C', team:'TOR', sal:4100 },
#               {id:286,name:"Kemba Walker", owned:30.95, pos:'PG', team:'BOS', sal:7600 },
#               {id:286,name:"Kemba Walker", owned:30.95, pos:'PG', team:'BOS', sal:7600 },
#               {id:286,name:"Kemba Walker", owned:30.95, pos:'PG', team:'BOS', sal:7600 },
#               {id:14,name:"Marcus Smart", owned:30.87, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:30.87, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:30.87, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:14,name:"Marcus Smart", owned:30.87, pos:'PG/SG', team:'BOS', sal:6000 },
#               {id:689,name:"Fred VanVleet", owned:30.43, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:30.43, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:30.43, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:689,name:"Fred VanVleet", owned:30.43, pos:'PG/SG', team:'TOR', sal:7800 },
#               {id:463,name:"Mike Conley", owned:30.05, pos:'PG', team:'UTA', sal:6800 },
#               {id:331,name:"Jordan Clarkson", owned:29.22, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:331,name:"Jordan Clarkson", owned:29.22, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:331,name:"Jordan Clarkson", owned:29.22, pos:'PG/SG', team:'UTA', sal:5400 },
#               {id:91,name:"Norman Powell", owned:28.45, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:28.45, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:91,name:"Norman Powell", owned:28.45, pos:'SG/SF', team:'TOR', sal:4900 },
#               {id:537,name:"Serge Ibaka", owned:26.7, pos:'C', team:'TOR', sal:6200 },
#               {id:537,name:"Serge Ibaka", owned:26.7, pos:'C', team:'TOR', sal:6200 },
#               {id:802,name:"Jayson Tatum", owned:25.5, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:25.5, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:25.5, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:802,name:"Jayson Tatum", owned:25.5, pos:'SF/PF', team:'BOS', sal:9200 },
#               {id:489,name:"Nikola Jokic", owned:23.11, pos:'C', team:'DEN', sal:9500 },
#               {id:913,name:"Torrey Craig", owned:21.86, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:21.86, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:21.86, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:21.86, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:913,name:"Torrey Craig", owned:21.86, pos:'SG/SF', team:'DEN', sal:3600 },
#               {id:88,name:"Kyle Lowry", owned:21.75, pos:'PG', team:'TOR', sal:7700 },
#               {id:88,name:"Kyle Lowry", owned:21.75, pos:'PG', team:'TOR', sal:7700 },
#               {id:88,name:"Kyle Lowry", owned:21.75, pos:'PG', team:'TOR', sal:7700 },
#               {id:953,name:"Robert Williams", owned:21.73, pos:'C', team:'BOS', sal:3300 },
#               {id:953,name:"Robert Williams", owned:21.73, pos:'C', team:'BOS', sal:3300 },
#               {id:562,name:"Joe Ingles", owned:20.15, pos:'SG/SF', team:'UTA', sal:5300 },
#               {id:1063,name:"Michael Porter Jr.", owned:18.39, pos:'SF/PF', team:'DEN', sal:5500 },
#               {id:1063,name:"Michael Porter Jr.", owned:18.39, pos:'SF/PF', team:'DEN', sal:5500 },
#               {id:686,name:"Pascal Siakam", owned:17.17, pos:'PF', team:'TOR', sal:8000 },
#               {id:686,name:"Pascal Siakam", owned:17.17, pos:'PF', team:'TOR', sal:8000 },
#               {id:686,name:"Pascal Siakam", owned:17.17, pos:'PF', team:'TOR', sal:8000 },
#               {id:701,name:"Georges Niang", owned:14.7, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:701,name:"Georges Niang", owned:14.7, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:701,name:"Georges Niang", owned:14.7, pos:'SF/PF', team:'UTA', sal:3500 },
#               {id:558,name:"Rudy Gobert", owned:12.21, pos:'C', team:'UTA', sal:7900 },
#               {id:485,name:"Gary Harris", owned:12.08, pos:'SG', team:'DEN', sal:3900 },
#               {id:485,name:"Gary Harris", owned:12.08, pos:'SG', team:'DEN', sal:3900 },
#               {id:204,name:"Paul Millsap", owned:10.19, pos:'PF/C', team:'DEN', sal:4700 },
#               {id:952,name:"Brad Wanamaker", owned:10.02, pos:'PG', team:'BOS', sal:3500 },
#               {id:952,name:"Brad Wanamaker", owned:10.02, pos:'PG', team:'BOS', sal:3500 },
#               {id:910,name:"Monte Morris", owned:9.31, pos:'PG', team:'DEN', sal:4200 },
#               {id:910,name:"Monte Morris", owned:9.31, pos:'PG', team:'DEN', sal:4200 },
#               {id:538,name:"Enes Kanter", owned:3.46, pos:'C', team:'BOS', sal:3400 },
#               {id:538,name:"Enes Kanter", owned:3.46, pos:'C', team:'BOS', sal:3400 },
#               {id:1123,name:"Terence Davis", owned:2.7, pos:'PG/SG', team:'TOR', sal:3400 },
#               {id:529,name:"Mason Plumlee", owned:2.41, pos:'C', team:'DEN', sal:3300 },
#               {id:529,name:"Mason Plumlee", owned:2.41, pos:'C', team:'DEN', sal:3300 },
#               {id:893,name:"PJ Dozier", owned:1.8, pos:'PG/SG', team:'DEN', sal:3000 },
#               {id:893,name:"PJ Dozier", owned:1.8, pos:'PG/SG', team:'DEN', sal:3000 },
#               {id:28,name:"Rondae Hollis-Jefferson", owned:1.62, pos:'PF/C', team:'TOR', sal:3200 },
#               {id:811,name:"Semi Ojeleye", owned:1.32, pos:'PF', team:'BOS', sal:3300 },
#               {id:811,name:"Semi Ojeleye", owned:1.32, pos:'PF', team:'BOS', sal:3300 },
#               {id:1104,name:"Grant Williams", owned:1.06, pos:'SF/PF', team:'BOS', sal:3100 },
#          ],
#      };
#
#      function posMatch(playerPos, posList){
#          if(playerPos == null || posList == null){
#              return true;
#          }
#          var pList = posList.split(",");
#          var ppList = playerPos.split("/");
#          for(var i=0; i < pList.length; i++){
#              for(var j =0; j < ppList.length; j++){
#                  if(pList[i] === ppList[j]){
#                      return true;
#                  }
#              }
#          }
#          return false;
#      }
#
#      function populateTable(table, piechart, data, isProjected){
#          var rows = '';
#          if(data != null && data.length > 0){
#              var pieData = [];
#              var posList = null;
#              if(selectedPos != null){
#                  posList = posMap[selectedPos];
#              }
#              for(var i=0; i < data.length; i++){
#                  var d = data[i];
#                  if(posMatch(d.pos, posList)){
#                      rows += '<tr><td class="playername" data-playerid="' + d.id + '">' + d.name + '</td><td>' + d.pos + '</td><td>' + d.team + '</td><td>$' + d.sal + '</td><td>' + d.owned + '%</td></tr>';
#                      pieData.push([ d.name, d.owned]);
#                  }
#              }
#              table.find('tbody').html(rows);
#
#              Highcharts.chart(piechart, {
#                  chart: {
#                      type: 'pie',
#                      options3d: {
#                          enabled: true,
#                          alpha: 45,
#                          beta: 0
#                      },
#                      backgroundColor:'rgba(255, 255, 255, 0.1)'
#                  },
#                  title: {
#                      text: ''
#                  },
#                  tooltip: {
#                      pointFormat: '{series.name}: <b>{point.y:.1f}%</b>'
#                  },
#                  exporting: {
#                      enabled: false
#                  },
#                  plotOptions: {
#                      pie: {
#                          allowPointSelect: true,
#                          cursor: 'pointer',
#                          depth: 35,
#                          dataLabels: {
#                              enabled: true,
#                              format: '{point.name}'
#                          }
#                      }
#                  },
#                  series: [{
#                      type: 'pie',
#                      name: 'Ownership Percentage',
#                      data: pieData
#                  }]
#              });
#          }else{
#              $('#' + piechart).hide();
#              if(isProjected){
#                  table.after('<h3>Projected Ownership information is not available for this period.</h3>');
#              }else{
#                  table.after('<h3>Actual Ownership information is not yet available. Ownership data will begin to be filled in shortly after a slate begins.</h3>');
#              }
#              table.hide();
#          }
#      }
#
#      function reloadData(projOnly){
#          if(!projOnly){
#              var res = (selResultIdx < actualResultsDict.length) ? actualResultsDict[selResultIdx] : null;
#              populateTable($('#tableTournament'), 'pieChartTournament', actualResultsDict[selResultIdx], false);
#          }
#          populateTable($('#projectedTournament'),'pieChartProjected', projectedSlatesDict[selProjectedSlateId], true);
#          FSCPlayer.attach(2, 1, 1, 1);
#      }
#
#      $(document).ready(function() {
#          //
#          reloadData(false);
#
#          //
#          $("#cbTournamentSlate").change(function () {
#              selProjectedSlateId = parseInt($(this).find(':selected').attr('value'));
#              reloadData(true);
#          });
#          $("#cbTournamentSlate").val(selProjectedSlateId);
#
#          $('#cbContestResult').change(function () {
#              selResultIdx = parseInt($(this).find(':selected').attr('value'));
#              reloadData(false);
#
#              var slate = slates[selResultIdx];
#              $('#actualResultSlateName').html(slate.name + ', ' + slate.games + ' games');
#          });
#          $("#cbContestResult").val(selResultIdx);
#          if(selResultIdx < slates.length){
#              var slate = slates[selResultIdx];
#              $('#actualResultSlateName').html(slate.name + ', ' + slate.games + ' games');
#          }
#
#          $('.posFilterChange').click(function (e) {
#              e.preventDefault();
#              var item = $(this);
#              selectedPos = item.attr('id');
#              $('.posFilterChange').parent().removeClass('active');
#              item.parent().addClass('active');
#              reloadData(false);
#          });
#      });
#      function toggleEle(cls, id){
#          $('.' + cls).hide();
#          $('#' + id).show();
#      }
#  </script>,
#  <script type="text/javascript">
#  	/*globals jQuery, window, Sys */
#  	(function ($, Sys) {
#  		function setUpLogin() {
#  			var actionLinks = $("a[id$=DNN_cmdLogin]");
#  			actionLinks.click(function () {
#  				if ($(this).hasClass("dnnDisabledAction")) {
#  					return false;
#  				}
#
#  				actionLinks.addClass("dnnDisabledAction");
#  			});
#  		}
#
#  		$(document).ready(function () {
#
#  			$('.dnnLoginService').on('keydown', function(e) {
#  				if (e.keyCode === 13) {
#  					var $loginButton = $('#dnn_ctr587_Login_Login_DNN_cmdLogin');
#  					if ($loginButton.hasClass("dnnDisabledAction")) {
#  						return false;
#  					}
#
#  					$loginButton.addClass("dnnDisabledAction");
#  					eval($loginButton.attr('href'));
#  					e.preventDefault();
#  					return false;
#  				}
#  			});
#
#  			setUpLogin();
#  			Sys.WebForms.PageRequestManager.getInstance().add_endRequest(function () {
#  				setUpLogin();
#  			});
#  		});
#  	}(jQuery, window.Sys));
#  </script>,
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-106589727-1"></script>,
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-106589727-1');
#  </script>,
#  <script>
#   (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#   branch.init('key_live_lmGwrKWNYtdBRTEZGXu3MacdDzfVTPQb');
#  </script>,
#  <script>
#    !function(f,b,e,v,n,t,s)
#    {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#    n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#    if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#    n.queue=[];t=b.createElement(e);t.async=!0;
#    t.src=v;s=b.getElementsByTagName(e)[0];
#    s.parentNode.insertBefore(t,s)}(window, document,'script',
#    'https://connect.facebook.net/en_US/fbevents.js');
#    fbq('init', '2417044738534806');
#    fbq('track', 'PageView');
#  </script>,
#  <script type="text/javascript">//<![CDATA[
#     /* Toggle User Properties Menu
#      -------------------------------------------*/
#  	$('.userName a').click(function (e) {
#  	    $(this).toggleClass('active');
#  	    $('.userMenu').fadeToggle('fast');
#  	    e.stopPropagation();
#  	});
#  	$(document.body).click(function () {
#  	    $('.userMenu').hide();
#  	    $('.userName a').removeClass("active");
#  	});
#  	$('#dnn_pnav li').mouseenter(function () {
#  	    $('.userMenu').hide();
#  	    $('.userName a').removeClass("active");
#  	});
#  	$('.userMenu').click(function (e) {
#  	    e.stopPropagation();
#  	});
#  </script>,
#  <script src="/Resources/Shared/scripts/initWidgets.js" type="text/javascript"></script>,
#  <script type="text/javascript">
#  //<![CDATA[
#  ;(function() {
#                          function loadHandler() {
#                              var hf = $get('StylesheetManager_TSSM');
#                              if (!hf._RSSM_init) { hf._RSSM_init = true; hf.value = ''; }
#                              hf.value += ';Telerik.Web.UI, Version=2013.2.717.40, Culture=neutral, PublicKeyToken=121fae78165ba3d4:en-US:a713c6a1-0827-4380-88eb-63855ca4c2d9:45085116:27c5704c';
#                              Sys.Application.remove_load(loadHandler);
#                          };
#                          Sys.Application.add_load(loadHandler);
#                      })();Sys.Application.add_init(function() {
#      $create(Telerik.Web.UI.RadAjaxLoadingPanel, {"initialDelayTime":0,"isSticky":false,"minDisplayTime":0,"skin":"Default","uniqueID":"dnn$ctr587$Login_Prog","zIndex":90000}, null, null, $get("dnn_ctr587_Login_Prog"));
#  });
#  Sys.Application.add_init(function() {
#      $create(Telerik.Web.UI.RadAjaxPanel, {"clientEvents":{OnRequestStart:"",OnResponseEnd:""},"enableAJAX":true,"enableHistory":false,"links":[],"loadingPanelID":"dnn_ctr587_Login_Prog","styles":[],"uniqueID":"dnn$ctr587$Login_UP"}, null, null, $get("dnn_ctr587_Login_UP"));
#  });
#  //]]>
#  </script>]

# %%
test= plyr_soup.find_all('li' ,attrs=  {'class':'player'})
#json.loads(test.find('input')['value'])

test[1]

slate = '39113'
slate_type = 'MAIN'

player_df = pd.DataFrame(columns = ['date','slate_id', 'type', 'player',  'salary','position', 'proj_fpts_roto','proj_ownr_roto'])

for player in plyr_soup.find_all('li' ,attrs=  {'class':'player'}):
    row = {}
    row['date'] = datetime.today().date()
    row['slate_id'] = slate
    row['type'] = slate_type
    row['player'] = player.find('a').text
    row['salary'] = player['data-salary']
    row['position'] = player['data-pos']
    row['proj_fpts_roto'] = player.find('span', attrs = {'class':'fpts'}).text
    row['proj_ownr_roto'] = player.find('span', attrs = {'class':'pown'}).text
   
    player_df = player_df.append(row, ignore_index=True)
    

    
player_df
# Out:
#           date slate_id  type                   player salary position  \
# 0   2020-09-01    39113  MAIN             Kemba Walker  $7.6K       PG
# 1   2020-09-01    39113  MAIN             Marcus Smart    $6K    PG/SG
# 2   2020-09-01    39113  MAIN             Jaylen Brown  $7.3K    SG/SF
# 3   2020-09-01    39113  MAIN             Jayson Tatum  $9.2K    SF/PF
# 4   2020-09-01    39113  MAIN             Daniel Theis  $5.2K     PF/C
# 5   2020-09-01    39113  MAIN      Robert Williams III  $3.3K        C
# 6   2020-09-01    39113  MAIN           Brad Wanamaker  $3.5K       PG
# 7   2020-09-01    39113  MAIN             Semi Ojeleye  $3.3K       PF
# 8   2020-09-01    39113  MAIN           Grant Williams  $3.1K    SF/PF
# 9   2020-09-01    39113  MAIN              Enes Kanter  $3.4K        C
# 10  2020-09-01    39113  MAIN           Romeo Langford    $3K    SG/SF
# 11  2020-09-01    39113  MAIN          Vincent Poirier    $3K        C
# 12  2020-09-01    39113  MAIN           Carsen Edwards    $3K       SG
# 13  2020-09-01    39113  MAIN               Tacko Fall    $3K        C
# 14  2020-09-01    39113  MAIN               Kyle Lowry  $7.7K       PG
# 15  2020-09-01    39113  MAIN            Fred VanVleet  $7.8K    PG/SG
# 16  2020-09-01    39113  MAIN               OG Anunoby  $4.8K    SF/PF
# 17  2020-09-01    39113  MAIN            Pascal Siakam    $8K       PF
# 18  2020-09-01    39113  MAIN               Marc Gasol  $4.1K        C
# 19  2020-09-01    39113  MAIN              Serge Ibaka  $6.2K        C
# 20  2020-09-01    39113  MAIN            Norman Powell  $4.9K    SG/SF
# 21  2020-09-01    39113  MAIN            Terence Davis  $3.4K    PG/SG
# 22  2020-09-01    39113  MAIN              Matt Thomas  $3.1K       SG
# 23  2020-09-01    39113  MAIN  Rondae Hollis-Jefferson  $3.2K     PF/C
# 24  2020-09-01    39113  MAIN            Chris Boucher    $3K     PF/C
# 25  2020-09-01    39113  MAIN          Stanley Johnson    $3K    SF/PF
# 26  2020-09-01    39113  MAIN              Paul Watson    $3K       SF
# 27  2020-09-01    39113  MAIN           Malcolm Miller    $3K    SG/SF
# 28  2020-09-01    39113  MAIN          Dewan Hernandez    $3K        C
# 29  2020-09-01    39113  MAIN              Mike Conley  $6.8K       PG
# 30  2020-09-01    39113  MAIN         Donovan Mitchell  $9.9K    PG/SG
# 31  2020-09-01    39113  MAIN               Joe Ingles  $5.3K    SG/SF
# 32  2020-09-01    39113  MAIN            Royce O'Neale  $4.5K    SF/PF
# 33  2020-09-01    39113  MAIN              Rudy Gobert  $7.9K        C
# 34  2020-09-01    39113  MAIN          Jordan Clarkson  $5.4K    PG/SG
# 35  2020-09-01    39113  MAIN            Georges Niang  $3.5K    SF/PF
# 36  2020-09-01    39113  MAIN             Tony Bradley  $3.1K        C
# 37  2020-09-01    39113  MAIN             Juwan Morgan  $3.4K       PF
# 38  2020-09-01    39113  MAIN          Emmanuel Mudiay    $3K       PG
# 39  2020-09-01    39113  MAIN                 Miye Oni    $3K    SG/SF
# 40  2020-09-01    39113  MAIN            Rayjon Tucker    $3K    SG/SF
# 41  2020-09-01    39113  MAIN         Jarrell Brantley    $3K       PF
# 42  2020-09-01    39113  MAIN      Nigel Williams-Goss    $3K       PG
# 43  2020-09-01    39113  MAIN             Jamal Murray  $9.7K    PG/SG
# 44  2020-09-01    39113  MAIN             Monte Morris  $4.2K       PG
# 45  2020-09-01    39113  MAIN             Jerami Grant  $5.1K    SF/PF
# 46  2020-09-01    39113  MAIN             Paul Millsap  $4.7K     PF/C
# 47  2020-09-01    39113  MAIN             Nikola Jokic  $9.5K        C
# 48  2020-09-01    39113  MAIN       Michael Porter Jr.  $5.5K    SF/PF
# 49  2020-09-01    39113  MAIN              Gary Harris  $3.9K       SG
# 50  2020-09-01    39113  MAIN            Mason Plumlee  $3.3K        C
# 51  2020-09-01    39113  MAIN             Torrey Craig  $3.6K    SG/SF
# 52  2020-09-01    39113  MAIN              P.J. Dozier    $3K    PG/SG
# 53  2020-09-01    39113  MAIN             Troy Daniels    $3K       SG
# 54  2020-09-01    39113  MAIN                  Bol Bol    $3K     PF/C
# 55  2020-09-01    39113  MAIN         Keita Bates-Diop    $3K    SF/PF
# 56  2020-09-01    39113  MAIN               Tyler Cook    $3K        C
# 57  2020-09-01    39113  MAIN              Noah Vonleh    $3K     PF/C
#
#    proj_fpts_roto proj_ownr_roto
# 0           38.27         32.20%
# 1           29.27         24.90%
# 2           38.88         40.50%
# 3            48.4         30.10%
# 4           28.07         33.30%
# 5            16.6         17.70%
# 6           14.01         18.70%
# 7            8.63          8.30%
# 8            5.99         11.40%
# 9               0
# 10              0
# 11              0
# 12              0
# 13              0
# 14           40.9         35.30%
# 15          39.43         28.10%
# 16          24.94            26%
# 17          42.36         37.40%
# 18          22.57         22.90%
# 19          27.53         18.70%
# 20          23.37         22.90%
# 21           8.75          8.30%
# 22              0
# 23              0
# 24              0
# 25              0
# 26              0
# 27              0
# 28              0
# 29          34.81         30.10%
# 30          47.69         32.20%
# 31          26.38         21.80%
# 32          23.89         20.80%
# 33          41.52         28.10%
# 34          26.58         24.90%
# 35          14.93         21.80%
# 36           6.45          5.70%
# 37           0.73          3.10%
# 38              0
# 39              0
# 40              0
# 41              0
# 42              0
# 43          46.66         31.20%
# 44          18.25         18.70%
# 45          25.44            26%
# 46          19.84         17.70%
# 47          50.06         30.10%
# 48          28.12         28.10%
# 49          14.09         13.50%
# 50          12.06         13.50%
# 51           9.55         13.50%
# 52              0
# 53              0
# 54              0
# 55              0
# 56              0
# 57              0
